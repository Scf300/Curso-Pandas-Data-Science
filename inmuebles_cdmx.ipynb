# %% [markdown]
# <a href="https://colab.research.google.com/github/Scf300/Curso-Pandas-Data-Science/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PANDAS**

# %% [markdown]
# ## **Importando la base de datos**

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv"
pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
# Separar por ;

pd.read_csv(url, sep=";")
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep=";")
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
datos.sample(10)
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 22421  Departamento    Lomas de Chapultepec             2        0       0
# 18155  Departamento  San Miguel Chapultepec             3        3       3
# 5334   Departamento                    Roma             2        1       0
# 4086   Departamento                Santa Fe             3        1       1
# 21888  Departamento               Del Valle             2        1       1
# 9660   Departamento    Lomas de Chapultepec             1        0       1
# 25108  Departamento                Santa Fe             3        2       2
# 13367  Departamento    Lomas de Chapultepec             3        4       3
# 782    Departamento                Santa Fe             4        3       2
# 1214   Departamento        Centro Histórico             1        1       0
#
#        Area     Valor  Condominio  Impuesto
# 22421    70   15750.0      1575.0     175.0
# 18155   136   12250.0      4060.0       NaN
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## **Exploracion Inicial de los datos**

# %%
datos.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 10574  Conjunto Comercial/Sala      Centro Histórico             0        0
# 12818    Departamento en Hotel              Coyoacán             2        1
# 6851              Departamento              Santa Fe             4        3
# 24732             Departamento              Santa Fe             2        1
# 13975  Conjunto Comercial/Sala      Centro Histórico             0        0
# 16478             Departamento              Coyoacán             2        1
# 19718             Departamento  Lomas de Chapultepec             4        2
# 17259             Tienda/Salón              Santa Fe             0        6
# 11265             Departamento              Coyoacán             3        1
# 1652         Edificio Completo              Narvarte             0        2
#
#        Suites  Area    Valor  Condominio  Impuesto
# 10574       0    33   2100.0      2005.5     430.5
# ...

# %%
# tamaño del dataframe
datos.shape
# Out:
# (25121, 9)

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
# Resumen de los datos
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos["Tipo"]
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[["Habitaciones", "Valor"]]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# ## **Demandas ML**

# %% [markdown]
# ### **Analisis exploratorio de datos**

# %% [markdown]
# #### **¿Cuáles son los valores promedio de alquiler por tipo de propiedad?**

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos["Valor"].mean()
# Out:
# np.float64(36885.05048392878)

# %%
# valores promedio de alquiler
datos.groupby("Tipo")["Valor"].mean(numeric_only= True)
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
datos.groupby("Tipo")["Valor"].mean(numeric_only=True).sort_values()
# Out:
# Tipo
# Cocineta                        4425.856061
# Posada/Chalé                    5180.000000
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Estudio                         8400.000000
# Loft                            9924.526316
# Departamento en Hotel          16285.430769
# Departamento                   18683.269431
# Casa                           31453.177064
# Tienda en Centro Comercial     32556.785714
# Rancho                         38014.375000
# Casa de Condominio             51428.609836
# Casa Comercial                 54735.841584
# Tienda/Salón                   56263.544252
# Conjunto Comercial/Sala        57675.214550
# Hotel                          87500.000000
# Loteo/Condominio               92166.666667
# Terreno Estándar              135364.444444
# Galpón/Depósito/Almacén       299984.140138
# Edificio Completo             409418.080645
# Industria                     420000.000000
# ...

# %%
# valores promedio de alquiler por tipo de propiedad
df_tipo_precio= datos.groupby("Tipo")["Valor"].mean(numeric_only=True).sort_values()
df_tipo_precio.plot(kind="barh", figsize= (8,8), color ="purple")
# Out:
# <Axes: ylabel='Tipo'>

# %%
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón', 'Casa Comercial','Terreno Estándar', 'Cochera/Estacionamiento', 'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Hotel', 'Loteo/Condominio', 'Industria']

# %%
datos.query("@inmuebles_comerciales in Tipo")
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
datos.query("@inmuebles_comerciales not in Tipo")
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = datos.query("@inmuebles_comerciales not in Tipo")
df.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
df_tipo_precio= df.groupby("Tipo")["Valor"].mean(numeric_only=True).sort_values()
df_tipo_precio.plot(kind="barh", figsize= (8,8), color ="purple")
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ####**¿Cuál es el porcentaje de cada tipo de propiedad en nuestra base de datos?"**

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
porcentaje_tipo = df.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind="bar", figsize= (12,8), color ="green", xlabel="Porcentajes", ylabel="Porcentaje")
# Out:
# <Axes: xlabel='Porcentajes', ylabel='Porcentaje'>

# %%
df.query("Tipo == 'Departamento'")
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df = df.query("Tipo == 'Departamento'")
df.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
df['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')
# Out:
#               proportion
# Tipo
# Departamento         1.0

# %%
# Guardando el DataFrame en una variable
df_ejemplo = df['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')

# %%
# Cambiando el nombre de la columna "Tipo" a "Porcentajes"
df_ejemplo.rename(columns={'Tipo': 'Porcentajes'}, inplace=True)

# Visualizando el DataFrame
df_ejemplo
# Out:
#               proportion
# Tipo
# Departamento         1.0

# %% [markdown]
# ####**Calcular el promedio de habitaciones por departamento.**

# %%
datos.groupby("Tipo")["Habitaciones"].mean(numeric_only= True)
# Out:
# Tipo
# Casa                           3.359633
# Casa Comercial                 1.801980
# Casa de Condominio             4.319672
# Casa de Vecindad               1.974684
# Cochera/Estacionamiento        0.064935
# Cocineta                       0.836088
# Conjunto Comercial/Sala        0.047175
# Departamento                   2.504199
# Departamento en Hotel          1.419780
# Edificio Completo              0.405530
# Estudio                        0.500000
# Galpón/Depósito/Almacén        0.069204
# Hotel                         25.500000
# Industria                      0.000000
# Loft                           1.078947
# Loteo/Condominio               0.000000
# Posada/Chalé                  23.000000
# Rancho                         5.125000
# Terreno Estándar               0.066667
# Tienda en Centro Comercial     0.055838
# Tienda/Salón                   0.011840
# Name: Habitaciones, dtype: float64

# %%
df_promedio_habitacion = datos.groupby("Tipo")["Habitaciones"].mean(numeric_only= True)

# %%
df_promedio_habitacion_sorted = df_promedio_habitacion.sort_values(ascending=False)

# %%
df_promedio_habitacion_sorted.plot(kind="bar", figsize= (12,8), color ="green", xlabel="Porcentajes", ylabel="Porcentaje")
# Out:
# <Axes: xlabel='Porcentajes', ylabel='Porcentaje'>

# %% [markdown]
# ####**Verificar cuántas colonias únicas existen en nuestra base de datos.**

# %%
datos["Colonia"].unique()
# Out:
# array(['Condesa', 'Polanco', 'Santa Fe', 'Centro Histórico', 'Del Valle',
#        'Roma', 'Narvarte', 'Lomas de Chapultepec', 'Coyoacán',
#        'San Pedro de los Pinos', 'San Ángel', 'San Jerónimo',
#        'Ciudad de los Deportes', 'Villa Coapa', 'Bosques de las Lomas',
#        'Juárez', 'Chapultepec', 'Lindavista', 'La Condesa',
#        'San Miguel Chapultepec', 'Mixcoac', 'El Rosedal',
#        'Nueva Santa María', 'Arboledas', 'Villa de Cortés', 'Casa Blanca',
#        'Bosques de Aragón', 'La Florida', 'Álvaro Obregón', 'Iztacalco',
#        'Peralvillo', 'Napoles', 'Nativitas', 'San Rafael', 'Vallejo',
#        'Tlalpan', 'Pueblo Culhuacán', 'San Antonio Tecomitl',
#        'Roma Norte', 'Industrial Vallejo', 'Iztapalapa',
#        'Santa Marta Acatitla', 'Villa de Guadalupe', 'Tláhuac',
#        'Lomas de Padierna', 'El Contadero', 'San Mateo', 'Las Águilas',
#        'Culhuacán CTM', 'Santa María la Ribera', 'El Arenal',
# ...

# %% [markdown]
# ####**Analizar qué colonias tienen el promedio de alquiler más alto.**

# %%
datos.groupby("Colonia")["Valor"].mean(numeric_only= True)
# Out:
# Colonia
# Ajusco                 20504.166667
# Arboledas               6173.924731
# Atlalilco               5705.000000
# Atlampa                 6607.500000
# Barrio Bravo           36253.636364
#                           ...
# Villa de Cortés       135737.411765
# Villa de Guadalupe     14326.564189
# Xochimilco             32025.000000
# Zacatenco               5176.250000
# Álvaro Obregón          3048.281250
# Name: Valor, Length: 88, dtype: float64

# %%
colonias_alquiler_alto = datos.groupby("Colonia")["Valor"].mean(numeric_only= True).sort_values(ascending=False)
colonias_alquiler_alto
# Out:
# Colonia
# San Juan Xalpa          420926.739130
# Nativitas               244684.395062
# La Merced               213292.770833
# Santa Marta Acatitla    166048.105263
# Villa de Cortés         135737.411765
#                             ...
# Álvaro Obregón            3048.281250
# San José Insurgentes      2660.000000
# El Rodeo                  2586.111111
# Tláhuac                   2481.818182
# Las Aguilas               2222.500000
# Name: Valor, Length: 88, dtype: float64

# %% [markdown]
# ####**Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.**

# %%
df_cinco_colonias_mas_altos = colonias_alquiler_alto.head(5)

# %%
colonias_alquiler_alto.head(5)
# Out:
# Colonia
# San Juan Xalpa          420926.739130
# Nativitas               244684.395062
# La Merced               213292.770833
# Santa Marta Acatitla    166048.105263
# Villa de Cortés         135737.411765
# Name: Valor, dtype: float64

# %%
df_cinco_colonias_mas_altos.plot(kind="bar", figsize= (12,8), color ="green", xlabel="Colonias", ylabel="Alquiler")
# Out:
# <Axes: xlabel='Colonias', ylabel='Alquiler'>

# %% [markdown]
# ###**Tratar datos nulos**

# %%
df.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
df.fillna(0)
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df = df.fillna(0)
df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# #### **Remover registros inconsistentes**

# %%
df.query("Valor == 0 or Condominio == 0")
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
df.query("Valor == 0 or Condominio == 0").index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
# datos a remover
df_remover = df.query("Valor == 0 or Condominio == 0").index

# %%
df.drop(df_remover, axis=0, inplace=True)

# %%
df.query("Valor == 0 or Condominio == 0")
# Out:
# Empty DataFrame
# Columns: [Tipo, Colonia, Habitaciones, Garages, Suites, Area, Valor, Condominio, Impuesto]
# Index: []

# %%
df.Tipo.unique()
# Out:
# array(['Departamento'], dtype=object)

# %%
df.drop("Tipo",axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 16366               Condesa             3        1       1   130  19250.0
# 13202               Condesa             1        0       0    36   6300.0
# 19844  Bosques de las Lomas             2        1       1   160  24500.0
# 9824               Santa Fe             4        0       4   223  29750.0
# 3706               Santa Fe             1        2       1   124  10500.0
# 20412              Coyoacán             3        2       1   150  22750.0
# 17180               Condesa             4        1       0   260  15750.0
# 21244              Santa Fe             3        2       1   200  21000.0
# 20174               Condesa             3        0       1   160  14000.0
# 3703              San Ángel             3        1       1   113  16800.0
#
#        Condominio  Impuesto
# 16366      4550.0    1039.5
# 13202      2117.5     238.0
# 19844      5705.0    1774.5
# 9824      10850.0    2450.0
# ...

# %% [markdown]
# ### **Filtros**

# %% [markdown]
# ####**Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200**

# %%
df.query("Habitaciones == 1 and Valor < 4200")
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
df1 = df.query("Habitaciones == 1 and Valor < 4200")

# %%
df1[df1["Valor"] > 4200]
# Out:
# Empty DataFrame
# Columns: [Colonia, Habitaciones, Garages, Suites, Area, Valor, Condominio, Impuesto]
# Index: []

# %% [markdown]
# #### **Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².**

# %%
df.query("Habitaciones >= 2 and Valor < 10500 and Area > 70")
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %%
df2 = df.query("Habitaciones >= 2 and Valor < 10500 and Area > 70")

# %% [markdown]
# ## **Guardando archivos**

# %%
df.to_csv("inmuebles_ml.csv")

# %%
pd.read_csv("inmuebles_ml.csv")
# Out:
#        Unnamed: 0               Colonia  Habitaciones  Garages  Suites  Area  \
# 0               3      Centro Histórico             1        0       0    15
# 1               4             Del Valle             1        0       0    48
# 2               8               Condesa             1        0       1    40
# 3              10               Condesa             4        3       1   243
# 4              13              Santa Fe             2        1       1    67
# ...           ...                   ...           ...      ...     ...   ...
# 14259       25111  Lomas de Chapultepec             3        0       1    80
# 14260       25113              Coyoacán             3        1       2   150
# 14261       25114              Narvarte             1        0       0    28
# 14262       25118               Mixcoac             2        1       0    48
# 14263       25119  Lomas de Chapultepec             2        0       0    70
#
#          Valor  Condominio  Impuesto
# ...

# %%
# borrando index
df.to_csv("inmuebles_ml.csv", index=False)

# %%
pd.read_csv("inmuebles_ml.csv")
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0          Centro Histórico             1        0       0    15   2800.0
# 1                 Del Valle             1        0       0    48   2800.0
# 2                   Condesa             1        0       1    40   7000.0
# 3                   Condesa             4        3       1   243  45500.0
# 4                  Santa Fe             2        1       1    67   5950.0
# ...                     ...           ...      ...     ...   ...      ...
# 14259  Lomas de Chapultepec             3        0       1    80  10500.0
# 14260              Coyoacán             3        1       2   150  52500.0
# 14261              Narvarte             1        0       0    28   3500.0
# 14262               Mixcoac             2        1       0    48   4900.0
# 14263  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 0          1365.0      70.0
# ...

# %%
# cambiar separador del archivo
df.to_csv("inmuebles_ml.csv", index=False, sep=";")

# %%
df1.to_csv("inmuebles_ml_filtro1.csv", index=False, sep=";")

# %%
df2.to_csv("inmuebles_ml_filtro2.csv", index=False, sep=";")

# %% [markdown]
# ## **Demandas de DEV**

# %% [markdown]
# ### **Crear columnas numericas**

# %% [markdown]
# ####**valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.**

# %%
datos = pd.read_csv(url, sep=";")
datos.shape
# Out:
# (25121, 9)

# %%
datos ["Valor_mensual"] = datos[ "Valor"] + datos[ "Condominio"]
datos.head ()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# ####**valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.**

# %%
datos ["Valor_anual"] = datos[ "Valor_mensual"] * 12 + datos["Impuesto"]

# %%
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual
# 25116       0   755  49000.0         NaN       NaN            NaN          NaN
# 25117       0    27   2800.0      1225.0      87.5         4025.0      48387.5
# 25118       0    48   4900.0      1781.5     129.5         6681.5      80307.5
# 25119       0    70  10500.0      2660.0       NaN        13160.0          NaN
# 25120       0   250  22750.0     14721.0    3881.5        37471.0     453533.5

# %% [markdown]
# ### **Crear Columnas Categoricas**

# %% [markdown]
# #### **Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.**

# %%
datos["Descripcion"] = datos["Tipo"] + " en " + datos["Colonia"] + " con " + datos["Habitaciones"].astype(str) + " habitacion(es) y " + datos["Garages"].astype(str) + " plazas de estacionamiento."

# %%
datos.head ()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion
# ...

# %%
datos.iloc[500].Descripcion
# Out:
# 'Departamento en Napoles con 1 habitacion(es) y 0 plazas de estacionamiento.'

# %% [markdown]
# #### **Tiene_suite: Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad.**

# %%
datos["Tiene_suite"] = datos["Suites"].apply(lambda x: "Si" if x > 0 else "No")

# %%
datos.sample(10)
# Out:
#                           Tipo                Colonia  Habitaciones  Garages  \
# 5384              Tienda/Salón               Santa Fe             0        1
# 17169  Conjunto Comercial/Sala               Santa Fe             0        0
# 22165                 Cocineta                 Juárez             1        0
# 10380  Conjunto Comercial/Sala               Coyoacán             0        0
# 24328                 Cocineta                   Roma             0        0
# 2500              Departamento     Villa de Guadalupe             3        1
# 7120              Departamento               Santa Fe             2        1
# 13495             Tienda/Salón  Jardines de San Mateo             0        0
# 16851             Departamento               Santa Fe             3        2
# 2378              Departamento                   Roma             2        1
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor_mensual  \
# ...
